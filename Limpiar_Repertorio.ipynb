# %%
import pandas as pd

# %%
# Primero leo el repertorio
repertorio = pd.read_csv('./graph_project_crawl/Repertorio-Reducido.csv',
                         sep=',', 
                         encoding='utf-8',
                         index_col = None)

# %%
# Ordeno el repertorio por el nombre del artísta
repertorio = repertorio.sort_values(by='artist_name')

# %%
# Hay cancionoes duplicadas (featurings duplicados), los elimino
repertorio = repertorio.drop_duplicates(subset=repertorio.columns).reset_index(drop=True)

# %%
repertorio
# Out:
#            artist_id artist_name feat_artist_id  \
# 0       mn0000516929      *NSYNC   mn0000861351
# 1       mn0000516929      *NSYNC   mn0000664817
# 2       mn0000516929      *NSYNC   mn0000664817
# 3       mn0000516929      *NSYNC   mn0000664817
# 4       mn0000516929      *NSYNC   mn0000664817
# 5       mn0000516929      *NSYNC   mn0000664817
# 6       mn0000516929      *NSYNC   mn0000664817
# 7       mn0000516929      *NSYNC   mn0000664817
# 8       mn0000516929      *NSYNC   mn0000101895
# 9       mn0000516929      *NSYNC   mn0000101895
# 10      mn0000516929      *NSYNC   mn0000337119
# 11      mn0000516929      *NSYNC   mn0000337119
# 12      mn0000516929      *NSYNC   mn0000337119
# 13      mn0000516929      *NSYNC   mn0000337119
# 14      mn0000516929      *NSYNC   mn0000337119
# 15      mn0000516929      *NSYNC   mn0000101895
# 16      mn0000516929      *NSYNC   mn0000101895
# 17      mn0000516929      *NSYNC   mn0000101895
# 18      mn0000516929      *NSYNC   mn0000101895
# 19      mn0000516929      *NSYNC   mn0000101895
# 20      mn0000516929      *NSYNC   mn0000101895
# 21      mn0000516929      *NSYNC   mn0000567809
# 22      mn0000516929      *NSYNC   mn0000567809
# 23      mn0000516929      *NSYNC   mn0000567809
# 24      mn0000516929      *NSYNC   mn0000567809
# 25      mn0000516929      *NSYNC   mn0000567809
# 26      mn0000516929      *NSYNC   mn0000567809
# 27      mn0000516929      *NSYNC   mn0000567809
# 28      mn0000516929      *NSYNC   mn0000567809
# 29      mn0000516929      *NSYNC   mn0000567809
# ...              ...         ...            ...
# 155921  mn0000690254      ZZ Top   mn0000156953
# 155922  mn0000690254      ZZ Top   mn0000156953
# 155923  mn0000690254      ZZ Top   mn0000156953
# 155924  mn0000690254      ZZ Top   mn0000156953
# 155925  mn0000690254      ZZ Top   mn0000156953
# 155926  mn0000690254      ZZ Top   mn0000156953
# 155927  mn0000690254      ZZ Top   mn0000156953
# 155928  mn0000690254      ZZ Top   mn0000156953
# 155929  mn0000690254      ZZ Top   mn0000156953
# 155930  mn0000690254      ZZ Top   mn0000156953
# 155931  mn0000690254      ZZ Top   mn0000156953
# 155932  mn0000690254      ZZ Top   mn0000156953
# 155933  mn0000690254      ZZ Top   mn0000156953
# 155934  mn0000690254      ZZ Top   mn0000156953
# 155935  mn0000690254      ZZ Top   mn0000156953
# 155936  mn0000690254      ZZ Top   mn0000156953
# 155937  mn0000690254      ZZ Top   mn0000156953
# 155938  mn0000690254      ZZ Top   mn0000156953
# 155939  mn0000690254      ZZ Top   mn0000156953
# 155940  mn0000690254      ZZ Top   mn0000156953
# 155941  mn0000690254      ZZ Top   mn0000156953
# 155942  mn0000690254      ZZ Top   mn0000156953
# 155943  mn0000690254      ZZ Top   mn0000156953
# 155944  mn0000690254      ZZ Top   mn0000156953
# 155945  mn0000690254      ZZ Top   mn0000156953
# 155946  mn0000690254      ZZ Top   mn0000156953
# 155947  mn0000690254      ZZ Top   mn0000156953
# 155948  mn0000690254      ZZ Top   mn0000156953
# 155949  mn0000690254      ZZ Top   mn0000156953
# 155950  mn0000690254      ZZ Top   mn0000156953
#
#                                                      song
# 0                                              Girlfriend
# 1                         Merry Christmas, Happy Holidays
# 2                                                More Fun
# 3                                     More Than a Feeling
# 4                                    Music from the Heart
# 5                                       Music Of My Heart
# 6                                       Music of My Heart
# 7                   Music of My Heart (Ft Gloria Estefan)
# 8                                        I Believe in You
# 9       I Don't Wanna Spend One More Christmas Without...
# 10                                        The Debut Album
# 11                             Desbaratando el Campamento
# 12                                       Digital Get Down
# 13                                            The Dispute
# 14                                          Do Your Thing
# 15                                            I Need Love
# 16      I Just Wanna Be with You [Plus Hidden Track: F...
# 17                                 I Just Wanna Be With U
# 18                            I Guess It's Christmas Time
# 19                                   I Drive Myself Crazy
# 20                               I Just Wanna Be With You
# 21                                      Trashin' the Camp
# 22                              Touring and Public Appeal
# 23                                         Together Again
# 24                           This Is Where the Party's At
# 25                      Turn Off The Light [Original Mix]
# 26              This I Promise You (Hex Hector Radio Mix)
# 27                     This I Promise You (Album Version)
# 28                                     This I Promise You
# 29                 Thinking of You (I Drive Myself Crazy)
# ...                                                   ...
# 155921                                     Manic Mechanic
# 155922                                  Made into a Movie
# 155923                               It's Too Easy Mañana
# 155924                                       It's So Hard
# 155925                                     It's Only Love
# 155926                                          It's Gone
# 155927                                 Isn't Love Amazing
# 155928                      Introduction by Ross Mitchell
# 155929                      If I Could Only Flag Her Down
# 155930                            I'm Bad, I'm Nationwide
# 155931                                      Mercury Blues
# 155932                                          Mescalero
# 155933                                  Mexican Blackbird
# 155934                                Hey Mr. Millionaire
# 155935                                            Hey Joe
# 155936                            Heaven, Hell or Houston
# 155937                                  Heartache In Blue
# 155938                                  Heart It on the X
# 155939                                  Heard It on the X
# 155940                                    Have You Heard?
# 155941                                     Have You Heard
# 155942                                        Hairdresser
# 155943                                    My Mind Is Gone
# 155944                            My Heads in Mississippi
# 155945                           My Head's in Mississippi
# 155946                                 Mushmouth Shoutin'
# 155947                           Move Me on Down the Line
# 155948                                      Miller's Farm
# 155949                                Have a Little Mercy
# 155950                                             Mellow
#
# [155951 rows x 4 columns]

# %%
j = {
    "glossary": {
        "title": "example glossary",
        "GlossDiv": {
            "title": "S",
            "GlossList": {
                "GlossEntry": {
                    "ID": "SGML",
                    "SortAs": "SGML",
                    "GlossTerm": "Standard Generalized Markup Language",
                    "Acronym": "SGML",
                    "Abbrev": "ISO 8879:1986",
                    "GlossDef": {
                        "para": "A meta-markup language, used to create markup languages such as DocBook.",
                        "GlossSeeAlso": ["GML", "XML"]
                    },
                    "GlossSee": "markup"
                }
            }
        }
    }
}

# %%
json_normalize(j)
# Out:
#   glossary.GlossDiv.GlossList.GlossEntry.Abbrev  \
# 0                                 ISO 8879:1986
#
#   glossary.GlossDiv.GlossList.GlossEntry.Acronym  \
# 0                                           SGML
#
#   glossary.GlossDiv.GlossList.GlossEntry.GlossDef.GlossSeeAlso  \
# 0                                         [GML, XML]
#
#   glossary.GlossDiv.GlossList.GlossEntry.GlossDef.para  \
# 0  A meta-markup language, used to create markup ...
#
#   glossary.GlossDiv.GlossList.GlossEntry.GlossSee  \
# 0                                          markup
#
#   glossary.GlossDiv.GlossList.GlossEntry.GlossTerm  \
# 0             Standard Generalized Markup Language
#
#   glossary.GlossDiv.GlossList.GlossEntry.ID  \
# 0                                      SGML
#
#   glossary.GlossDiv.GlossList.GlossEntry.SortAs glossary.GlossDiv.title  \
# 0                                          SGML                       S
#
#      glossary.title
# 0  example glossary
