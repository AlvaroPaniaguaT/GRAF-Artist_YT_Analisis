# %% [markdown]
# # Creando el grafo

# %% [markdown]
# Hemos leído ya el repertorio de la pagina https://www.allmusic.com/ para la lista de artistas que disponemos. Estos datos contienen 4 campos:
#
# - Identificador del artista
# - Nombre del artista
# - Identificador del artista con el que comparte una cancion
# - Cancion que comparten
#
# El objetivo es obtener un documento en el cual tengamos unicamente los nombres de los artistas que son los extremos de la arista y el peso de la arista, del tipo.
#
# |Artist|Collaborator|Number collaborations|
# |--|--|--|
# |Metallica|ACDC|6|

# %%
import pandas as pd
import unidecode
import numpy as np

# %%
# Primero leo el repertorio
repertorio = pd.read_csv('./Data/Repertorio-Final.csv',
                         sep=',', 
                         encoding='utf-8',
                         index_col = None)

# Todas las canciones a minúscula
repertorio['song'] = repertorio['song'].str.lower()

""" Elimina los acentos en las canciones"""
repertorio['song'] = repertorio['song'].str.normalize('NFD').str.encode('ascii', errors='ignore').str.decode('utf-8')
repertorio.head(5)
# Out:
#       artist_id artist_name feat_artist_id      feat_artist_name  \
# 0  mn0000690254      ZZ Top   mn0000503563  The Moving Sidewalks
# 1  mn0000690254      ZZ Top   mn0000503563  The Moving Sidewalks
# 2  mn0000246960       Wham!   mn0000545074        George Michael
# 3  mn0000246960       Wham!   mn0000545074        George Michael
# 4  mn0000246960       Wham!   mn0000545074        George Michael
#
#                       song
# 0        you make me shake
# 1  you were so close to me
# 2               young guns
# 3               young guns
# 4  young guns (go for it!)

# %%
# Ordeno el repertorio por el nombre del artísta
repertorio = repertorio.sort_values(by='artist_name')
repertorio.head()
# Out:
#          artist_id artist_name feat_artist_id feat_artist_name  \
# 5671  mn0000516929      *NSYNC   mn0000567809   Modern Talking
# 5770  mn0000516929      *NSYNC   mn0000101895              Joe
# 5771  mn0000516929      *NSYNC   mn0000101895              Joe
# 5772  mn0000516929      *NSYNC   mn0000101895              Joe
# 5773  mn0000516929      *NSYNC   mn0000101895              Joe
#
#                           song
# 5671                you got it
# 5770      i'll never stop(vcd)
# 5771        if i'm not the one
# 5772        if i'm not the one
# 5773  if only in heaven's eyes

# %%
# Hay cancionoes duplicadas (featurings duplicados), los elimino
repertorio = repertorio.drop_duplicates(subset=repertorio.columns).reset_index(drop=True)

# %%
repertorio['Number collaborations'] = 1
repertorio.head()
# Out:
#       artist_id artist_name feat_artist_id feat_artist_name  \
# 0  mn0000516929      *NSYNC   mn0000567809   Modern Talking
# 1  mn0000516929      *NSYNC   mn0000101895              Joe
# 2  mn0000516929      *NSYNC   mn0000101895              Joe
# 3  mn0000516929      *NSYNC   mn0000101895              Joe
# 4  mn0000516929      *NSYNC   mn0000101895              Joe
#
#                        song  Number collaborations
# 0                you got it                      1
# 1      i'll never stop(vcd)                      1
# 2        if i'm not the one                      1
# 3  if only in heaven's eyes                      1
# 4           in conversation                      1

# %%
f = {'Number collaborations': 'sum', 'artist_name': 'first', 'feat_artist_name': 'first'}
test = repertorio.groupby(['artist_id', 'feat_artist_id'],
                          as_index=False).agg(f)


test.head()
# Out:
#       artist_id feat_artist_id  Number collaborations     artist_name  \
# 0  mn0000000534   mn0000344634                     10      All Saints
# 1  mn0000000534   mn0000642542                      6      All Saints
# 2  mn0000000534   mn0000815862                      8      All Saints
# 3  mn0000000534   mn0001233067                     50      All Saints
# 4  mn0000002578   mn0000236246                     19  Tanita Tikaram
#
#       feat_artist_name
# 0        Melanie Blatt
# 1       Burt Bacharach
# 2  All-Saints Ensemble
# 3       Danny Thompson
# 4           Mark Isham

# %%
output = pd.DataFrame()
for _, row in test.iterrows():
    inverted = test[(test['artist_name'] == row['feat_artist_name']) & (test['feat_artist_name'] == row['artist_name'])]
    if inverted.empty:
        output = output.append(row)

output
# Out:
#       Number collaborations     artist_id       artist_name feat_artist_id  \
# 0                      10.0  mn0000000534        All Saints   mn0000344634
# 1                       6.0  mn0000000534        All Saints   mn0000642542
# 2                       8.0  mn0000000534        All Saints   mn0000815862
# 3                      50.0  mn0000000534        All Saints   mn0001233067
# 4                      19.0  mn0000002578    Tanita Tikaram   mn0000236246
# 5                       3.0  mn0000002578    Tanita Tikaram   mn0000495877
# 6                       5.0  mn0000002748        Pata Negra   mn0000869068
# 7                       6.0  mn0000002748        Pata Negra   mn0001589240
# 8                       2.0  mn0000004332  Sharleen Spiteri   mn0000302774
# 9                       4.0  mn0000004332  Sharleen Spiteri   mn0000333648
# 10                    159.0  mn0000004852            Selena   mn0000005945
# 11                      7.0  mn0000004852            Selena   mn0000040407
# 12                      7.0  mn0000004852            Selena   mn0000093629
# 13                     10.0  mn0000004852            Selena   mn0000187907
# 14                     10.0  mn0000004852            Selena   mn0000370097
# 15                     42.0  mn0000004852            Selena   mn0000798858
# 16                      4.0  mn0000004852            Selena   mn0000922050
# 17                      4.0  mn0000004852            Selena   mn0001383740
# 18                     13.0  mn0000005307       Alicia Keys   mn0000065618
# 19                     28.0  mn0000005307       Alicia Keys   mn0000150962
# 20                      3.0  mn0000005307       Alicia Keys   mn0000197355
# 21                      2.0  mn0000005307       Alicia Keys   mn0000201983
# 23                      6.0  mn0000005307       Alicia Keys   mn0000312890
# 24                     18.0  mn0000005307       Alicia Keys   mn0000319338
# 25                      2.0  mn0000005307       Alicia Keys   mn0000420967
# 26                     16.0  mn0000005307       Alicia Keys   mn0000550233
# 27                     30.0  mn0000005307       Alicia Keys   mn0000630035
# 28                     15.0  mn0000005307       Alicia Keys   mn0000771269
# 29                     23.0  mn0000005307       Alicia Keys   mn0000774551
# 30                      5.0  mn0000005307       Alicia Keys   mn0000780734
# ...                     ...           ...               ...            ...
# 5181                    2.0  mn0003276902      Shawn Mendes   mn0003163663
# 5183                    4.0  mn0003276902      Shawn Mendes   mn0003524877
# 5185                    2.0  mn0003345212      Charlie Puth   mn0000159298
# 5186                    3.0  mn0003345212      Charlie Puth   mn0000272689
# 5208                 Red Café
# 5209                   G-Eazy
# 5210                 Rita Ora
# 5211                    Migos
# 5212               Lil Yachty
# 5213                   Offset
# 5214                Bad Bunny
# 5215                 J Balvin
#
# [4757 rows x 5 columns]

# %%
output['Number collaborations'] = output['Number collaborations'].astype(np.int32)

# %%
output = output.sort_values(by='artist_name')
output.head(15)
# Out:
#       Number collaborations     artist_id artist_name feat_artist_id  \
# 2942                      5  mn0000516929      *NSYNC   mn0000337119
# 2948                     15  mn0000516929      *NSYNC   mn0000861351
# 2947                      5  mn0000516929      *NSYNC   mn0000850607
# 2946                      1  mn0000516929      *NSYNC   mn0000799081
# 2945                      4  mn0000516929      *NSYNC   mn0000759187
# 2944                      7  mn0000516929      *NSYNC   mn0000664817
# 2941                     31  mn0000516929      *NSYNC   mn0000101895
# 2822                     21  mn0000480108        A-ha   mn0001178546
# 2823                     45  mn0000480108        A-ha   mn0001489096
# 2820                      5  mn0000480108        A-ha   mn0000325459
# 2821                     11  mn0000480108        A-ha   mn0000716816
# 3171                     17  mn0000578999     Aaliyah   mn0000745225
# 3170                     21  mn0000578999     Aaliyah   mn0000668393
# 3172                      5  mn0000578999     Aaliyah   mn0000748713
# 3169                     10  mn0000578999     Aaliyah   mn0000662797
#
#        feat_artist_name
# 2942       Phil Collins
# 2948              Nelly
# 2947    Rosie O'Donnell
# 2946         Full Force
# 2945             Blaque
# 2944     Gloria Estefan
# 2941                Joe
# 2822           Blue Zoo
# 2823  Electric Rudeboyz
# 2820             R.E.M.
# 2821     Wolfgang Petry
# 3171             Static
# 3170        DJ /rupture
# 3172         Slick Rick
# 3169           Ginuwine

# %%
output.to_csv('./Data/Lista_Grafo.csv', sep=";", encoding="utf-8", index=None)

# %%
artist_list = open('./Data/Lista_Artista.txt', 'r', encoding='utf-8').read().split('\n')

# %%
channels_data = pd.read_csv('./Data/Channels_Data.csv', sep=';', encoding="utf-8")
channels_data.head()
# Out:
#                  channel_id         channel_title  view_count  \
# 0  UCsiSmzL5G7VS_pfKMXqmcjw             NSYNCVEVO   572035818
# 1  UC-xTVl97pv9ftbOu8UfVy_Q  NatalieMerchantVideo    26199696
# 2  UCeEi1My3KTXHT0SG1JkR9gA                  a-ha   216942980
# 3  UCneR_qQ1NE_u9neBSEJJ7lg          MsAaliyahJay    87678984
# 4  UCa_4DcdTB9QfK0LY9-7qWuQ              AbbaVEVO  1527781457
#
#    subscriber_count               playlist_id
# 0            474128  UUsiSmzL5G7VS_pfKMXqmcjw
# 1             40106  UU-xTVl97pv9ftbOu8UfVy_Q
# 2            338830  UUeEi1My3KTXHT0SG1JkR9gA
# 3           1256852  UUneR_qQ1NE_u9neBSEJJ7lg
# 4           1008765  UUa_4DcdTB9QfK0LY9-7qWuQ

# %%
stats_list = channels_data['subscriber_count'].tolist()

# %%
for artist in artist_list:
    if item in
# Out:
# 663

# %%
# Out:
# 687
